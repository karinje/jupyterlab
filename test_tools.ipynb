# %% [raw]
# # Test Notebook for Tools
#
# This notebook will be used to test the YDoc-based tools.

# %% [markdown]
# # Test Markdown Cell
#
# This cell was inserted by the tools!

# %%
# Updated code
print("This code was updated!")
10 * 10
# Out:
# This code was updated!
# 100

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)
plt.figure(figsize=(8, 4))
plt.plot(x, y)
plt.title("Sine Wave")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# # Test Markdown Cell
#
# This cell was inserted by the tools!

# %%
# Updated code
print("This code was updated!")
10 * 10
# Out:
# This code was updated!
# 100

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)
plt.figure(figsize=(8, 4))
plt.plot(x, y)
plt.title("Sine Wave")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# # Index Flow Markdown
#
# Inserted via index-based test.

# %%
# Updated code
print("This code was updated!")
10 * 10
# Out:
# This code was updated!
# 100

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)
plt.figure(figsize=(8, 4))
plt.plot(x, y)
plt.title("Sine Wave")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.grid(True)
plt.show()

# %%
raise ValueError("This is a test error")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 raise ValueError('This is a test error')
#
# ValueError: This is a test error
